# %% [markdown]
# Nome: Francisco Jerônimo da Silva Júnior <br>
# Matrícula: 4333399 <br>
# Curso: Ciência da Computação <br>
# E-mail: franciscojeronimo@alu.ufc.br <br>

# %% [markdown]
# ### 1. Escolha e baixe um conjunto de dados da plataforma Kaggle (https://www.kaggle.com/datasets), que tenha ao menos um atributo numérico. Carregue os dados através da biblioteca Pandas ou Dask.

# %%
# carregar a biblioteca 
import pandas as pd

# %%
df = pd.read_csv('athletes.csv')

# %% [markdown]
# O dataset corresponde aos atletas que participaram dos jogos olímpicos do Rio de Janeiro em 2016.

# %% [markdown]
# ### 2. Exiba as 20 primeiras linhas do conjunto de dados selecionado.

# %%
df.head(20)
# Out:
#            id                      name nationality     sex       dob  height  \
# 0   736041664            A Jesus Garcia         ESP    male  10/17/69    1.72
# 1   532037425                A Lam Shin         KOR  female   9/23/86    1.68
# 2   435962603               Aaron Brown         CAN    male   5/27/92    1.98
# 3   521041435                Aaron Cook         MDA    male    1/2/91    1.83
# 4    33922579                Aaron Gate         NZL    male  11/26/90    1.81
# 5   173071782               Aaron Royle         AUS    male   1/26/90    1.80
# 6   266237702             Aaron Russell         USA    male    6/4/93    2.05
# 7   382571888             Aaron Younger         AUS    male   9/25/91    1.93
# 8    87689776       Aauri Lorena Bokesa         ESP  female  12/14/88    1.80
# 9   997877719           Ababel Yeshaneh         ETH  female   7/22/91    1.65
# 10  343694681               Abadi Hadis         ETH    male   11/6/97    1.70
# ...

# %% [markdown]
# ### 3. Exiba o número de linhas de dados presentes no conjunto de dados selecionado.

# %%
df.shape[0]
# Out:
# 11538

# %% [markdown]
# ### 4. Exiba a média, o desvio padrão, e os valores mínimo e máximo de um campo numérico do conjunto de dados selecionado.

# %%
# pode-se acessar um conjunto de medidas via describe
df[['height', 'weight']].describe()
# Out:
#              height        weight
# count  11208.000000  10879.000000
# mean       1.766282     72.068205
# std        0.112719     16.177334
# min        1.210000     31.000000
# 25%        1.690000     60.000000
# 50%        1.760000     70.000000
# 75%        1.840000     81.000000
# max        2.210000    170.000000

# %%
df['height'].mean()
# Out:
# 1.7662821199143461

# %%
df['height'].std()
# Out:
# 0.11271869117624643

# %%
df['height'].min()
# Out:
# 1.21

# %%
df['height'].max()
# Out:
# 2.21

# %% [markdown]
# ### 5. Exiba as 5 primeiras linhas do conjunto de dados ordenado em ordem decrescente pelo mesmo campo numérico usado por você na questão 4.

# %%
df.sort_values(by=['height'], ascending=False).head()
# Out:
#              id          name nationality   sex      dob  height  weight  \
# 5690  905417640  Kevin Cordes         USA  male  8/13/93    2.21    88.0
# 7766  824855418      Muhao Li         CHN  male   6/2/92    2.18   115.0
# 8769  321163659       Qi Zhou         CHN  male  1/16/96    2.17    95.0
# 8486  899162102     Pau Gasol         ESP  male   7/6/80    2.15   115.0
# 9251  648750303   Rudy Gobert         FRA  male  6/26/92    2.15   113.0
#
#            sport  gold  silver  bronze
# 5690    aquatics     1       0       0
# 7766  basketball     0       0       0
# 8769  basketball     0       0       0
# 8486  basketball     0       0       1
# 9251  basketball     0       0       0
